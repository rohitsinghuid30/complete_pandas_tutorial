# %% [markdown]
# # Accessing Data with Pandas

# %%
import pandas as pd

# %%
coffee=pd.read_csv('./src/warmup-data/coffee.csv')

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.day
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16880\1287571608.py in ?()
# ----> 1 coffee.day
#
# c:\Users\rohit\Desktop\rohit\Pandas\complete_pandas_tutorial\venv\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'day'

# %%
coffee.Day
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.Coffee Type
# Out:
#   Cell In[21], line 1
#     coffee.Coffee Type
#                   ^
# SyntaxError: invalid syntax

# %%
coffee["Day"]
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
coffee["Coffee Type"]
# Out:
# 0     Espresso
# 1        Latte
# 2     Espresso
# 3        Latte
# 4     Espresso
# 5        Latte
# 6     Espresso
# 7        Latte
# 8     Espresso
# 9        Latte
# 10    Espresso
# 11       Latte
# 12    Espresso
# 13       Latte
# Name: Coffee Type, dtype: object

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.Units Sold
# Out:
#   Cell In[25], line 1
#     coffee.Units Sold
#                  ^
# SyntaxError: invalid syntax

# %%
coffee["Units Sold"]
# Out:
# 0     25
# 1     15
# 2     30
# 3     20
# 4     35
# 5     25
# 6     40
# 7     30
# 8     45
# 9     35
# 10    45
# 11    35
# 12    45
# 13    35
# Name: Units Sold, dtype: int64

# %%
bios=pd.read_csv("./src/data/bios.csv")

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.tail()
# Out:
#         athlete_id                 name   born_date        born_city  \
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225       André Foussard  1899-05-19            Niort
# 145499      149814        Bill Phillips  1913-07-15     Dulwich Hill
#
#             born_region born_country        NOC  height_cm  weight_kg  \
# 145495       Sverdlovsk          RUS        ROC      167.0       61.0
# 145496           Moskva          RUS        ROC      168.0       65.0
# 145497      Arkhangelsk          RUS        ROC      163.0       55.0
# 145498      Deux-Sèvres          FRA     France      166.0        NaN
# 145499  New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20

# %%
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
bios.loc[bios['height_cm']> 216]
# Out:
#         athlete_id                   name   born_date           born_city  \
# 5089          5108     Viktor Pankrashkin  1957-06-19     Moskva (Moscow)
# 5583          5606   Paulinho Villas Boas  1963-01-26           São Paulo
# 5673          5696         Gunther Behnke  1963-01-19          Leverkusen
# 5716          5739               Uwe Blab  1962-03-26    München (Munich)
# 5781          5804         Tommy Burleson  1952-02-24           Crossnore
# 5796          5819          Andy Campbell  1956-07-21           Melbourne
# 6420          6451          Jānis Krūmiņš  1930-01-30               Cēsis
# 6504          6537            Luc Longley  1969-01-19           Melbourne
# 6978          7013        Arvydas Sabonis  1964-12-19              Kaunas
# 7074          7111         Paulo da Silva  1963-07-21           São Paulo
# 7188          7226     Vladimir Tkachenko  1957-09-20           Golovinka
# 7281          7320       Stojko Vranković  1964-01-22               Drniš
# ...

# %%
bios.loc[bios['height_cm']> 216 and bios['height_cm'] < 217]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7032\1701018452.py in ?()
# ----> 1 bios.loc[bios['height_cm']> 216 and bios['height_cm'] < 217]
#
# c:\Users\rohit\Desktop\rohit\Pandas\complete_pandas_tutorial\venv\lib\site-packages\pandas\core\generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# # Filtering Data

# %%
bios.loc[bios['height_cm']> 216, ['name', 'height_cm']]
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# 107408       Peter John Ramos      219.0
# 112312           Stanko Barać      217.0
# 112337          Hamed Haddadi      218.0
# 118676        Dmitry Musersky      219.0
# 120266           Zhang Zhaoxu      221.0
# ...

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.loc[bios['born_city']=='Meulan']
# Out:
#         athlete_id             name   born_date born_city born_region  \
# 1                2   Arnaud Boetsch  1969-04-01    Meulan    Yvelines
# 36583        36876     René Boucher  1928-12-01    Meulan    Yvelines
# 89182        89894  Frédéric Esther  1972-06-08    Meulan    Yvelines
# 120970      122932  Rahamatou Dramé  1985-04-01    Meulan    Yvelines
# 131061      133823       Élie Konki  1992-04-06    Meulan    Yvelines
# 139397      142869   Julien Mertine  1988-06-25    Meulan    Yvelines
#
#        born_country     NOC  height_cm  weight_kg   died_date
# 1               FRA  France      183.0       76.0         NaN
# 36583           FRA  France        NaN        NaN  2018-11-03
# 89182           FRA  France      176.0       71.0         NaN
# 120970          FRA    Mali      168.0       55.0         NaN
# 131061          FRA  France      170.0       52.0         NaN
# 139397          FRA  France        NaN        NaN         NaN

# %%
bios.loc[bios['born_city']=='Meulan', ['name', 'born_date', 'born_city']]
# Out:
#                    name   born_date born_city
# 1        Arnaud Boetsch  1969-04-01    Meulan
# 36583      René Boucher  1928-12-01    Meulan
# 89182   Frédéric Esther  1972-06-08    Meulan
# 120970  Rahamatou Dramé  1985-04-01    Meulan
# 131061       Élie Konki  1992-04-06    Meulan
# 139397   Julien Mertine  1988-06-25    Meulan

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
# filter by country name
bios.loc[bios['NOC']=='France', ['name', 'born_city', 'born_date', 'NOC']]
# Out:
#                          name         born_city   born_date     NOC
# 0       Jean-François Blanchy          Bordeaux  1886-12-12  France
# 1              Arnaud Boetsch            Meulan  1969-04-01  France
# 2                Jean Borotra          Biarritz  1898-08-13  France
# 3             Jacques Brugnon       Paris VIIIe  1895-05-11  France
# 4                Albert Canet        Wandsworth  1878-04-17  France
# ...                       ...               ...         ...     ...
# 144646         Alexia Queyrel  Clermont-Ferrand  1999-06-03  France
# 144647      Léo Le Blé Jaques   Chêne-Bougeries  1997-01-02  France
# 144648            Liam Tourki          Grenoble  1999-03-25  France
# 144649      Gwendoline Daudet  Nogent-sur-Marne  1998-11-28  France
# 145498         André Foussard             Niort  1899-05-19  France
#
# [6339 rows x 4 columns]

# %%
bios.loc[bios['weight_kg']==60, ['name', 'NOC', 'weight_kg', 'born_date']]
# Out:
#                          name                   NOC  weight_kg   born_date
# 139           Steffen Fetzner  Germany West Germany       60.0  1968-08-17
# 201            Lo Chuen Tsung      Hong Kong, China       60.0  1963-10-08
# 203              Vong Lu Veng      Hong Kong, China       60.0  1950-03-12
# 207               Andrea Dakó               Hungary       60.0  1972-08-12
# 253           Tri Kusharyanto             Indonesia       60.0  1974-01-18
# ...                       ...                   ...        ...         ...
# 144527            Lisa Jensen               Denmark       60.0  1997-02-26
# 144626         Carola Niemelä               Finland       60.0  1999-02-11
# 144627  Coralie Frasse Sombet                France       60.0  1991-04-08
# 144752             Sára Pónya               Hungary       60.0  1999-05-14
# 145056    Yevgeniya Burtasova                   ROC       60.0  1993-07-09
#
# [3728 rows x 4 columns]

# %%
# get weight in another way
bios[bios['weight_kg']==60]
# Out:
#         athlete_id                   name   born_date   born_city  \
# 139            140        Steffen Fetzner  1968-08-17   Karlsruhe
# 201            202         Lo Chuen Tsung  1963-10-08         NaN
# 203            204           Vong Lu Veng  1950-03-12         NaN
# 207            208            Andrea Dakó  1972-08-12    Budapest
# 253            254        Tri Kusharyanto  1974-01-18  Yogyakarta
# ...            ...                    ...         ...         ...
# 144527      148219            Lisa Jensen  1997-02-26         NaN
# 144626      148318         Carola Niemelä  1999-02-11       Rauma
# 144627      148320  Coralie Frasse Sombet  1991-04-08         NaN
# 144752      148453             Sára Pónya  1999-05-14   Esztergom
# 145056      148768    Yevgeniya Burtasova  1993-07-09    Guryevsk
#
#                        born_region born_country                   NOC  \
# 139              Baden-Württemberg          GER  Germany West Germany
# ...

# %%
# Get a Specific column
bios[bios['height_cm']==166]['name', 'born_date', 'height_cm', 'weight_kg', 'NOc']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\rohit\Desktop\rohit\Pandas\complete_pandas_tutorial\venv\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('name', 'born_date', 'height_cm', 'weight_kg', 'NOc')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Get a Specific column
bios[bios['height_cm']>160]['name', 'born_date', 'height_cm', 'weight_kg']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\rohit\Desktop\rohit\Pandas\complete_pandas_tutorial\venv\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('name', 'born_date', 'height_cm', 'weight_kg')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Get a Specific column
bios[bios['height_cm']>160][['name', 'born_date', 'height_cm', 'weight_kg']]
# Out:
#                        name   born_date  height_cm  weight_kg
# 1            Arnaud Boetsch  1969-04-01      183.0       76.0
# 2              Jean Borotra  1898-08-13      183.0       76.0
# 3           Jacques Brugnon  1895-05-11      168.0       64.0
# 5         Nicolas Chatelain  1970-01-13      181.0       70.0
# 6             Patrick Chila  1969-11-27      180.0       73.0
# ...                     ...         ...        ...        ...
# 145494        George Wright  1890-07-21      183.0        NaN
# 145495    Polina Luchnikova  2002-01-30      167.0       61.0
# 145496  Valeriya Merkusheva  1999-09-20      168.0       65.0
# 145497      Yuliya Smirnova  1998-05-08      163.0       55.0
# 145498       André Foussard  1899-05-19      166.0        NaN
#
# [99691 rows x 4 columns]

# %%
# and operator
bios[(bios['height_cm']>160) & (bios['born_country'=='USA'])]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\rohit\Desktop\rohit\Pandas\complete_pandas_tutorial\venv\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 2
#       1 # and operator
# ...

# %%
# and operator
bios[(bios['height_cm']>160) & (bios['born_country']=='USA')]
# Out:
#         athlete_id                  name   born_date          born_city  \
# 54              55         Monique Javer  1967-07-22         Burlingame
# 960            964      Xóchitl Escobedo  1968-09-17        West Covina
# 1345          1352            Laura Berg  1975-01-06   Santa Fe Springs
# 1346          1353          Gillian Boxx  1973-09-01            Fontana
# 1356          1363  Sheila Cornell-Douty  1962-02-26             Encino
# ...            ...                   ...         ...                ...
# 144388      148078          Zhang Xifang  2000-12-20  Commerce Township
# 144398      148088               Jian An  1990-09-15             Irvine
# 144400      148090      Shimisi Jieruimi  1989-04-13           Dearborn
# 144977      148686      Atle Lie McGrath  2000-04-21         Burlington
# 145468      149195     Justin Abdelkader  1987-02-25           Muskegon
#
#        born_region born_country                         NOC  height_cm  \
# ...
